# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Side by Side bar plot
plotdata = pd.DataFrame({
"2018":[57,67,77,83],
"2019":[68,73,80,79],
"2020":[73,78,80,85]},
index=["Django", "Gafur", "Tommy", "Ronnie"])
plotdata.plot(kind="bar",figsize=(15, 8))
plt.title("FIFA ratings")
plt.xlabel("Footballer")
plt.ylabel("Ratings")
# Out:
# Text(0, 0.5, 'Ratings')

# %%
#Sine wave
x=np.linspace(0,2*np.pi,num=10000)
y=np.sin(x)
plt.plot(x,y)

# %%
#Histplot
df=np.random.randint(0,50,size=25)
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %%
from mpl_toolkits import mplot3d
# Creating dataset
z = np.random.randint(100, size =(50))
x = np.random.randint(80, size =(50))
y = np.random.randint(60, size =(50))
 
# Creating figure
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(x, y, z, color = "green")
plt.title("simple 3D scatter plot")
 
# show plot
plt.show()

# %%
#Surface plot
# Creating dataset
x = np.outer(np.linspace(-3, 3, 32), np.ones(32))
y = x.copy().T # transpose
z = (np.sin(x **2) + np.cos(y **2) )
 
# Creating figure
fig = plt.figure(figsize =(14, 9))
ax = plt.axes(projection ='3d')
 
# Creating plot
ax.plot_surface(x, y, z)
 
# show plot
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/codespace/.local/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %%
plt.style.use('_mpl-gallery')

# make data:
np.random.seed(10)
D = np.random.normal((3, 5, 4), (0.75, 1.00, 0.75), (200, 3))

# plot:
fig, ax = plt.subplots()

vp = ax.violinplot(D)
# styling:
for body in vp['bodies']:
    body.set_alpha(0.9)
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
#Plot bar chart of 5 number summary of iris.csv
df=pd.read_csv('Iris.csv')
df.describe().plot(kind='box',figsize=(20,10))
# Out:
# <Axes: >

# %%
#q4
import random
df=pd.DataFrame({'Name':range(50),
'Dept':random.choices(['CSE','ICT','MCA','ICT','ECE'],k=50),
'Sub1':np.random.randint(0,100,size=50),
'Sub2':np.random.randint(0,100,size=50),
'Sub3':np.random.randint(0,100,size=50),
'Sub4':np.random.randint(0,100,size=50),
'Sub5':np.random.randint(0,100,size=50)})

# %%
df.describe().plot(kind='bar',figsize=(20,10))
# Out:
# <Axes: >

# %%
df.groupby(by='Dept',axis=0).plot(kind='bar',figsize=(20,10))
# Out:
# Dept
# CSE    Axes(0.01,0.01;0.98x0.98)
# ECE    Axes(0.01,0.01;0.98x0.98)
# ICT    Axes(0.01,0.01;0.98x0.98)
# MCA    Axes(0.01,0.01;0.98x0.98)
# dtype: object

# %%
# Create a figure and axis object
fig, ax = plt.subplots()

# Set the width of each bar
bar_width = 0.15

# Create a bar for each subject and department
for i in range(len(['Sub1'])):
    x = [j + bar_width * i for j in range(len(departments))]
    ax.bar(x, [row[i] for row in data], width=bar_width, label=subjects[i])

# Set the x-axis ticks and labels
ax.set_xticks([j + 2 * bar_width for j in range(len(departments))])
ax.set_xticklabels(departments)

# Add a legend and title
ax.legend()
ax.set_title('Performance by department and subject')

# Show the plot
plt.show()
# Out:
# /home/codespace/.local/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:512: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = self.plt.figure(figsize=self.figsize)
# Dept  Sub1
# CSE   0       Axes(0.01,0.01;0.98x0.98)
#       29      Axes(0.01,0.01;0.98x0.98)
#       37      Axes(0.01,0.01;0.98x0.98)
#       43      Axes(0.01,0.01;0.98x0.98)
#       49      Axes(0.01,0.01;0.98x0.98)
#       57      Axes(0.01,0.01;0.98x0.98)
#       65      Axes(0.01,0.01;0.98x0.98)
#       67      Axes(0.01,0.01;0.98x0.98)
#       72      Axes(0.01,0.01;0.98x0.98)
#       86      Axes(0.01,0.01;0.98x0.98)
#       88      Axes(0.01,0.01;0.98x0.98)
#       89      Axes(0.01,0.01;0.98x0.98)
# ...

# %%
matrix1=np.random.randint(0,10,size=(3,3))
matrix2=np.random.randint(0,10,size=(3,3))

# %%
#Matrix multiplication
np.dot(matrix1,matrix2)
# Out:
# array([[ 55, 134,   5],
#        [ 12,  51,  15],
#        [ 40, 116,  20]])

# %%
matrix1.T
# Out:
# array([[1, 3, 4],
#        [9, 0, 6],
#        [9, 3, 6]])

# %%
np.linalg.inv(matrix1)
# Out:
# array([[-2.00000000e-01, -2.77555756e-17,  3.00000000e-01],
#        [-6.66666667e-02, -3.33333333e-01,  2.66666667e-01],
#        [ 2.00000000e-01,  3.33333333e-01, -3.00000000e-01]])
